# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv(r"C:\Users\91866\Downloads\Global Population Trends(2016-2022).csv")

# %%
df
# Out:
#           Country  Year Total Population Urban Population Rural Population  \
# 0     Afghanistan  2017                -                -                -
# 1     Afghanistan  2018       36,686,784        9,353,296       27,333,488
# 2     Afghanistan  2019       37,769,499        9,727,157       28,042,342
# 3     Afghanistan  2020       38,972,230       10,142,913       28,829,317
# 4     Afghanistan  2021       40,099,462       10,551,772       29,547,690
# ...           ...   ...              ...              ...              ...
# 1068     Zimbabwe  2017                -                -                -
# 1069     Zimbabwe  2018       15,052,184        4,848,158       10,204,026
# 1070     Zimbabwe  2019       15,354,608        4,945,719       10,408,889
# 1071     Zimbabwe  2020       15,669,666        5,052,214       10,617,452
# 1072     Zimbabwe  2021       15,993,524        5,166,388       10,827,136
#
#      Population Density Life Expectancy  Birth Rate  Death Rate  \
# ...

# %%
df.describe()
# Out:
#               Year   Birth Rate   Death Rate
# count  1073.000000  1073.000000  1073.000000
# mean   2019.013048    18.801519     7.841907
# std       1.410190     9.903449     2.973418
# min    2017.000000     0.000000     0.000000
# 25%    2018.000000    10.620000     6.067000
# 50%    2019.000000    16.025000     7.396000
# 75%    2020.000000    25.921000     9.313000
# max    2021.000000    46.351000    21.700000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1073 entries, 0 to 1072
# Data columns (total 12 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Country                1073 non-null   object
#  1   Year                   1073 non-null   int64
#  2   Total Population       1073 non-null   object
#  3   Urban Population       1073 non-null   object
#  4   Rural Population       1073 non-null   object
#  5   Population Density     1073 non-null   object
#  6   Life Expectancy        1073 non-null   object
#  7   Birth Rate             1073 non-null   float64
#  8   Death Rate             1073 non-null   float64
#  9   Fertility Rate         1073 non-null   object
#  10  Infant Mortality Rate  1073 non-null   object
#  11  Growth Rate            1073 non-null   object
# dtypes: float64(2), int64(1), object(9)
# memory usage: 100.7+ KB

# %%
df.drop("Population Density",axis=1)
# Out:
#           Country  Year Total Population Urban Population Rural Population  \
# 0     Afghanistan  2017                -                -                -
# 1     Afghanistan  2018       36,686,784        9,353,296       27,333,488
# 2     Afghanistan  2019       37,769,499        9,727,157       28,042,342
# 3     Afghanistan  2020       38,972,230       10,142,913       28,829,317
# 4     Afghanistan  2021       40,099,462       10,551,772       29,547,690
# ...           ...   ...              ...              ...              ...
# 1068     Zimbabwe  2017                -                -                -
# 1069     Zimbabwe  2018       15,052,184        4,848,158       10,204,026
# 1070     Zimbabwe  2019       15,354,608        4,945,719       10,408,889
# 1071     Zimbabwe  2020       15,669,666        5,052,214       10,617,452
# 1072     Zimbabwe  2021       15,993,524        5,166,388       10,827,136
#
#      Life Expectancy  Birth Rate  Death Rate Fertility Rate  \
# ...

# %%
df
# Out:
#           Country  Year Total Population Urban Population Rural Population  \
# 0     Afghanistan  2017                -                -                -
# 1     Afghanistan  2018       36,686,784        9,353,296       27,333,488
# 2     Afghanistan  2019       37,769,499        9,727,157       28,042,342
# 3     Afghanistan  2020       38,972,230       10,142,913       28,829,317
# 4     Afghanistan  2021       40,099,462       10,551,772       29,547,690
# ...           ...   ...              ...              ...              ...
# 1068     Zimbabwe  2017                -                -                -
# 1069     Zimbabwe  2018       15,052,184        4,848,158       10,204,026
# 1070     Zimbabwe  2019       15,354,608        4,945,719       10,408,889
# 1071     Zimbabwe  2020       15,669,666        5,052,214       10,617,452
# 1072     Zimbabwe  2021       15,993,524        5,166,388       10,827,136
#
#      Population Density Life Expectancy  Birth Rate  Death Rate  \
# ...

# %%
df.drop(["Country"],axis=1,inplace=True)

# %%
df
# Out:
#       Year Total Population Urban Population Rural Population  \
# 0     2017                -                -                -
# 1     2018       36,686,784        9,353,296       27,333,488
# 2     2019       37,769,499        9,727,157       28,042,342
# 3     2020       38,972,230       10,142,913       28,829,317
# 4     2021       40,099,462       10,551,772       29,547,690
# ...    ...              ...              ...              ...
# 1068  2017                -                -                -
# 1069  2018       15,052,184        4,848,158       10,204,026
# 1070  2019       15,354,608        4,945,719       10,408,889
# 1071  2020       15,669,666        5,052,214       10,617,452
# 1072  2021       15,993,524        5,166,388       10,827,136
#
#      Population Density Life Expectancy  Birth Rate  Death Rate  \
# 0                    55            63.0      37.342       7.027
# 1                    56            63.0      36.927       6.981
# ...

# %%
df.isnull().sum()
# Out:
# Year                     0
# Total Population         0
# Urban Population         0
# Rural Population         0
# Population Density       0
# Life Expectancy          0
# Birth Rate               0
# Death Rate               0
# Fertility Rate           0
# Infant Mortality Rate    0
# Growth Rate              0
# dtype: int64

# %%
sns.scatterplot(x="Birth Rate",y="Death Rate",data=df)
plt.show()

# %%
df["Total Population"].value_counts()
# Out:
# -             209
# 4,601,157       1
# 2,076,694       1
# 2,072,531       1
# 2,065,092       1
#              ...
# 32,833,031      1
# 32,648          1
# 32,685          1
# 32,709          1
# 15,993,524      1
# Name: Total Population, Length: 865, dtype: int64

# %%
sns.lineplot(data=df)
# Out:
# <Axes: >

# %%
sns.countplot(x="Year",data=df)
plt.show()

# %%
year=df["Year"].value_counts().sort_index()

# %% [raw]
# year

# %%
year
# Out:
# 2017    209
# 2018    216
# 2019    216
# 2020    216
# 2021    216
# Name: Year, dtype: int64

# %%
sns.scatterplot(x=year.index,y=year.values,marker="^",size=year.index,hue=year.index,sizes=(50,200),palette='gist_ncar')
plt.legend(loc=3)
plt.show()

# %%
sns.barplot(x=df.index, y=df['Growth Rate'])
plt.show()

# %%
data = df[["Birth Rate", "Death Rate"]]

# %%
corr = data.corr(numeric_only = False)
sns.heatmap(corr, cmap="Blues", annot=True)
plt.show()
